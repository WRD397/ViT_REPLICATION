# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pwd
# Out:
# /kaggle/working

# %%
# !ls -al
# Out:
# total 12
# drwxr-xr-x 3 root root 4096 Jun 12 16:45 .
# drwxr-xr-x 5 root root 4096 Jun 12 16:45 ..
# drwxr-xr-x 2 root root 4096 Jun 12 16:45 .virtual_documents

# %%
# !git clone https://github.com/WRD397/ViT_REPLICATION.git
# Out:
# Cloning into 'ViT_REPLICATION'...
# remote: Enumerating objects: 192, done.
# remote: Counting objects: 100% (192/192), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 192 (delta 86), reused 146 (delta 47), pack-reused 0 (from 0)
# Receiving objects: 100% (192/192), 79.40 KiB | 1.85 MiB/s, done.
# Resolving deltas: 100% (86/86), done.

# %%
# %cd ViT_REPLICATION
# Out:
# /kaggle/working/ViT_REPLICATION

# %%
# !ls -al
# Out:
# total 48
# drwxr-xr-x 8 root root 4096 Jun 12 16:45 .
# drwxr-xr-x 4 root root 4096 Jun 12 16:45 ..
# drwxr-xr-x 2 root root 4096 Jun 12 16:45 config
# drwxr-xr-x 8 root root 4096 Jun 12 16:45 .git
# -rw-r--r-- 1 root root  185 Jun 12 16:45 .gitignore
# -rw-r--r-- 1 root root 1071 Jun 12 16:45 LICENSE
# drwxr-xr-x 2 root root 4096 Jun 12 16:45 model
# drwxr-xr-x 2 root root 4096 Jun 12 16:45 notebooks
# -rw-r--r-- 1 root root  657 Jun 12 16:45 README.md
# -rw-r--r-- 1 root root 1601 Jun 12 16:45 requirements.txt
# drwxr-xr-x 2 root root 4096 Jun 12 16:45 scripts
# drwxr-xr-x 2 root root 4096 Jun 12 16:45 utils

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: asttokens==3.0.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: certifi==2025.4.26 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (2025.4.26)
# Requirement already satisfied: charset-normalizer==3.4.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (3.4.2)
# Requirement already satisfied: comm==0.2.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (0.2.2)
# Collecting contourpy==1.3.2 (from -r requirements.txt (line 5))
#   Downloading contourpy-1.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: cycler==0.12.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (0.12.1)
# Collecting debugpy==1.8.14 (from -r requirements.txt (line 7))
#   Downloading debugpy-1.8.14-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting decorator==5.2.1 (from -r requirements.txt (line 8))
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting exceptiongroup==1.3.0 (from -r requirements.txt (line 9))
#   Downloading exceptiongroup-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting executing==2.2.0 (from -r requirements.txt (line 10))
#   Downloading executing-2.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: filelock==3.18.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (3.18.0)
# Collecting fonttools==4.58.1 (from -r requirements.txt (line 12))
#   Downloading fonttools-4.58.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 3.5 MB/s eta 0:00:00
# Collecting fsspec==2025.5.1 (from -r requirements.txt (line 13))
#   Downloading fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Collecting hf-xet==1.1.3 (from -r requirements.txt (line 14))
#   Downloading hf_xet-1.1.3-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# Collecting huggingface-hub==0.32.4 (from -r requirements.txt (line 15))
#   Downloading huggingface_hub-0.32.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: idna==3.10 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (3.10)
# Collecting ipykernel==6.29.5 (from -r requirements.txt (line 17))
#   Downloading ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting ipython==8.36.0 (from -r requirements.txt (line 18))
#   Downloading ipython-8.36.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: jedi==0.19.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 19)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 20)) (3.1.6)
# Requirement already satisfied: jupyter_client==8.6.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 21)) (8.6.3)
# Collecting jupyter_core==5.8.1 (from -r requirements.txt (line 22))
#   Downloading jupyter_core-5.8.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: kiwisolver==1.4.8 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 23)) (1.4.8)
# Requirement already satisfied: MarkupSafe==3.0.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 24)) (3.0.2)
# Collecting matplotlib==3.10.3 (from -r requirements.txt (line 25))
#   Downloading matplotlib-3.10.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 26)) (0.1.7)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 27)) (1.3.0)
# Requirement already satisfied: nest-asyncio==1.6.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 28)) (1.6.0)
# Requirement already satisfied: networkx==3.4.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 29)) (3.4.2)
# Collecting numpy==2.2.6 (from -r requirements.txt (line 30))
#   Downloading numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.8 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.6.4.1 (from -r requirements.txt (line 31))
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from -r requirements.txt (line 32))
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from -r requirements.txt (line 33))
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from -r requirements.txt (line 34))
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from -r requirements.txt (line 35))
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from -r requirements.txt (line 36))
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from -r requirements.txt (line 37))
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from -r requirements.txt (line 38))
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from -r requirements.txt (line 39))
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from -r requirements.txt (line 40))
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from -r requirements.txt (line 41))
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: nvidia-ml-py==12.575.51 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 42)) (12.575.51)
# Collecting nvidia-nccl-cu12==2.26.2 (from -r requirements.txt (line 43))
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from -r requirements.txt (line 44))
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from -r requirements.txt (line 45))
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: packaging==25.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 46)) (25.0)
# Requirement already satisfied: pandas==2.2.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 47)) (2.2.3)
# Requirement already satisfied: parso==0.8.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 48)) (0.8.4)
# Requirement already satisfied: pexpect==4.9.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 49)) (4.9.0)
# Collecting pillow==11.2.1 (from -r requirements.txt (line 50))
#   Downloading pillow-11.2.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Requirement already satisfied: platformdirs==4.3.8 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 51)) (4.3.8)
# Collecting prompt_toolkit==3.0.51 (from -r requirements.txt (line 52))
#   Downloading prompt_toolkit-3.0.51-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: psutil==7.0.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 53)) (7.0.0)
# Requirement already satisfied: ptyprocess==0.7.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 54)) (0.7.0)
# Collecting pure_eval==0.2.3 (from -r requirements.txt (line 55))
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: Pygments==2.19.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 56)) (2.19.1)
# Requirement already satisfied: pynvml==12.0.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 57)) (12.0.0)
# Collecting pyparsing==3.2.3 (from -r requirements.txt (line 58))
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 59)) (2.9.0.post0)
# Collecting python-dotenv==1.1.0 (from -r requirements.txt (line 60))
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pytz==2025.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 61)) (2025.2)
# Requirement already satisfied: PyYAML==6.0.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 62)) (6.0.2)
# Collecting pyzmq==26.4.0 (from -r requirements.txt (line 63))
#   Downloading pyzmq-26.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Requirement already satisfied: regex==2024.11.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 64)) (2024.11.6)
# Requirement already satisfied: requests==2.32.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 65)) (2.32.3)
# Requirement already satisfied: safetensors==0.5.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 66)) (0.5.3)
# Collecting seaborn==0.13.2 (from -r requirements.txt (line 67))
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: six==1.17.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 68)) (1.17.0)
# Collecting stack-data==0.6.3 (from -r requirements.txt (line 69))
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting sympy==1.14.0 (from -r requirements.txt (line 70))
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: timm==1.0.15 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 71)) (1.0.15)
# Requirement already satisfied: tokenizers==0.21.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 72)) (0.21.1)
# Collecting torch==2.7.0 (from -r requirements.txt (line 73))
#   Downloading torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting torchvision==0.22.0 (from -r requirements.txt (line 74))
#   Downloading torchvision-0.22.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting tornado==6.5.1 (from -r requirements.txt (line 75))
#   Downloading tornado-6.5.1-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.8 kB)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 76)) (4.67.1)
# Collecting traitlets==5.14.3 (from -r requirements.txt (line 77))
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting transformers==4.52.4 (from -r requirements.txt (line 78))
#   Downloading transformers-4.52.4-py3-none-any.whl.metadata (38 kB)
# Collecting triton==3.3.0 (from -r requirements.txt (line 79))
#   Downloading triton-3.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: typing_extensions==4.13.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 80)) (4.13.2)
# Requirement already satisfied: tzdata==2025.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 81)) (2025.2)
# Requirement already satisfied: urllib3==2.4.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 82)) (2.4.0)
# Requirement already satisfied: wcwidth==0.2.13 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 83)) (0.2.13)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/dist-packages (from triton==3.3.0->-r requirements.txt (line 79)) (75.2.0)
# Downloading contourpy-1.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (326 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.2/326.2 kB 11.2 MB/s eta 0:00:00
# Downloading debugpy-1.8.14-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 55.7 MB/s eta 0:00:0000:01
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading exceptiongroup-1.3.0-py3-none-any.whl (16 kB)
# Downloading executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Downloading fonttools-4.58.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 95.2 MB/s eta 0:00:00:00:01
# Downloading fsspec-2025.5.1-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 14.2 MB/s eta 0:00:00
# Downloading hf_xet-1.1.3-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 94.4 MB/s eta 0:00:00:00:01
# Downloading huggingface_hub-0.32.4-py3-none-any.whl (512 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.1/512.1 kB 29.6 MB/s eta 0:00:00
# Downloading ipykernel-6.29.5-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 7.7 MB/s eta 0:00:00
# Downloading ipython-8.36.0-py3-none-any.whl (831 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.1/831.1 kB 41.7 MB/s eta 0:00:00
# Downloading jupyter_core-5.8.1-py3-none-any.whl (28 kB)
# Downloading matplotlib-3.10.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 108.5 MB/s eta 0:00:0000:0100:01
# Downloading numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 89.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 4.3 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 111.8 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 54.5 MB/s eta 0:00:0000:0100:01m
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 49.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 2.9 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 6.0 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 43.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 10.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 2.1 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 10.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 8.4 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 91.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 kB 6.7 MB/s eta 0:00:00
# Downloading pillow-11.2.1-cp311-cp311-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 98.6 MB/s eta 0:00:00:00:01
# Downloading prompt_toolkit-3.0.51-py3-none-any.whl (387 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.8/387.8 kB 24.9 MB/s eta 0:00:00
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 8.3 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading pyzmq-26.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (862 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.4/862.4 kB 46.7 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 20.1 MB/s eta 0:00:00
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 102.3 MB/s eta 0:00:0000:01
# Downloading torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl (865.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.2/865.2 MB 1.0 MB/s eta 0:00:000:00:0100:01
# Downloading torchvision-0.22.0-cp311-cp311-manylinux_2_28_x86_64.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 56.6 MB/s eta 0:00:00:00:0100:01
# Downloading tornado-6.5.1-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.3/443.3 kB 30.7 MB/s eta 0:00:00
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 6.3 MB/s eta 0:00:00
# Downloading transformers-4.52.4-py3-none-any.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 112.2 MB/s eta 0:00:0000:010:01
# Downloading triton-3.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 MB 11.1 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: pure_eval, nvidia-cusparselt-cu12, triton, traitlets, tornado, sympy, pyzmq, python-dotenv, pyparsing, prompt_toolkit, pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, hf-xet, fsspec, fonttools, executing, exceptiongroup, decorator, debugpy, stack-data, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jupyter_core, huggingface-hub, contourpy, nvidia-cusolver-cu12, matplotlib, ipython, transformers, torch, seaborn, ipykernel, torchvision
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.6.2
#     Uninstalling nvidia-cusparselt-cu12-0.6.2:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.6.2
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.4.2
#     Uninstalling tornado-6.4.2:
#       Successfully uninstalled tornado-6.4.2
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 24.0.1
#     Uninstalling pyzmq-24.0.1:
#       Successfully uninstalled pyzmq-24.0.1
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: prompt_toolkit
#     Found existing installation: prompt_toolkit 3.0.50
#     Uninstalling prompt_toolkit-3.0.50:
#       Successfully uninstalled prompt_toolkit-3.0.50
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.10.19
#     Uninstalling nvidia-curand-cu12-10.3.10.19:
#       Successfully uninstalled nvidia-curand-cu12-10.3.10.19
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.4.127
#     Uninstalling nvidia-cuda-runtime-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.4.127
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.4.127
#     Uninstalling nvidia-cuda-cupti-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.4.127
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.9.0.13
#     Uninstalling nvidia-cublas-cu12-12.9.0.13:
#       Successfully uninstalled nvidia-cublas-cu12-12.9.0.13
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: hf-xet
#     Found existing installation: hf-xet 1.1.0
#     Uninstalling hf-xet-1.1.0:
#       Successfully uninstalled hf-xet-1.1.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.57.0
#     Uninstalling fonttools-4.57.0:
#       Successfully uninstalled fonttools-4.57.0
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: debugpy
#     Found existing installation: debugpy 1.8.0
#     Uninstalling debugpy-1.8.0:
#       Successfully uninstalled debugpy-1.8.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.9.5
#     Uninstalling nvidia-cusparse-cu12-12.5.9.5:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.9.5
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.4.0.6
#     Uninstalling nvidia-cufft-cu12-11.4.0.6:
#       Successfully uninstalled nvidia-cufft-cu12-11.4.0.6
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: jupyter_core
#     Found existing installation: jupyter_core 5.7.2
#     Uninstalling jupyter_core-5.7.2:
#       Successfully uninstalled jupyter_core-5.7.2
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.31.1
#     Uninstalling huggingface-hub-0.31.1:
#       Successfully uninstalled huggingface-hub-0.31.1
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.3.1
#     Uninstalling contourpy-1.3.1:
#       Successfully uninstalled contourpy-1.3.1
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.4.40
#     Uninstalling nvidia-cusolver-cu12-11.7.4.40:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.4.40
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.2
#     Uninstalling matplotlib-3.7.2:
#       Successfully uninstalled matplotlib-3.7.2
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.51.3
#     Uninstalling transformers-4.51.3:
#       Successfully uninstalled transformers-4.51.3
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.17.1
#     Uninstalling ipykernel-6.17.1:
#       Successfully uninstalled ipykernel-6.17.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.21.0+cu124
#     Uninstalling torchvision-0.21.0+cu124:
#       Successfully uninstalled torchvision-0.21.0+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.2.6 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.15.2 which is incompatible.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.5.1 which is incompatible.
# ydata-profiling 4.16.1 requires matplotlib<=3.10,>=3.5, but you have matplotlib 3.10.3 which is incompatible.
# ydata-profiling 4.16.1 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.1 which is incompatible.
# google-colab 1.0.0 requires ipykernel==6.17.1, but you have ipykernel 6.29.5 which is incompatible.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.36.0 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.2.1 which is incompatible.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.7.0 which is incompatible.
# bigframes 1.42.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.5.1 which is incompatible.
# fastai 2.7.19 requires torch<2.7,>=1.10, but you have torch 2.7.0 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# pandas-gbq 0.28.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Successfully installed contourpy-1.3.2 debugpy-1.8.14 decorator-5.2.1 exceptiongroup-1.3.0 executing-2.2.0 fonttools-4.58.1 fsspec-2025.5.1 hf-xet-1.1.3 huggingface-hub-0.32.4 ipykernel-6.29.5 ipython-8.36.0 jupyter_core-5.8.1 matplotlib-3.10.3 numpy-2.2.6 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 pillow-11.2.1 prompt_toolkit-3.0.51 pure_eval-0.2.3 pyparsing-3.2.3 python-dotenv-1.1.0 pyzmq-26.4.0 seaborn-0.13.2 stack-data-0.6.3 sympy-1.14.0 torch-2.7.0 torchvision-0.22.0 tornado-6.5.1 traitlets-5.14.3 transformers-4.52.4 triton-3.3.0

# %%
# !pip install tinyimagenet
# Out:
# Requirement already satisfied: tinyimagenet in /usr/local/lib/python3.11/dist-packages (0.9.9)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from tinyimagenet) (0.22.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision->tinyimagenet) (2.2.6)
# Requirement already satisfied: torch==2.7.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->tinyimagenet) (2.7.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->tinyimagenet) (11.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (1.11.1.6)
# Requirement already satisfied: triton==3.3.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.0->torchvision->tinyimagenet) (3.3.0)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/dist-packages (from triton==3.3.0->torch==2.7.0->torchvision->tinyimagenet) (75.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.13.3->torch==2.7.0->torchvision->tinyimagenet) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.7.0->torchvision->tinyimagenet) (3.0.2)

# %% [markdown]
# ### Dataloader Class

# %%
# !pwd
# Out:
# /kaggle/working/ViT_REPLICATION

# %%
# !echo "ROOT_PATH='/kaggle/working/ViT_REPLICATION'" >.env

# %%
import sys
import os
from dotenv import load_dotenv
load_dotenv()
ROOT_DIR_PATH = os.environ.get('ROOT_PATH')
ROOT_DIR_PATH
# Out:
# '/kaggle/working/ViT_REPLICATION'

# %% [markdown]
# # training

# %%
# !git pull
# Out:
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 12 (delta 6), reused 10 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (12/12), 1.57 KiB | 322.00 KiB/s, done.
# From https://github.com/WRD397/ViT_REPLICATION
#    1880d2b..dc9c2ac  main       -> origin/main
# Updating 1880d2b..dc9c2ac
# Fast-forward
#  config/vit_config.yaml |  5 +++--
#  model/vit.py           | 23 ++++++++++++-----------
#  scripts/train.py       | 30 ++++++++++++++++++++++++------
#  3 files changed, 39 insertions(+), 19 deletions(-)

# %%
# !python scripts/train.py
# Out:
# Using device: cuda
# -----------
# Label Smoothening is Enabled
# LR Scheduler is Disabled
# LR SchedulerWarmup is Enabled
# MixUp is Disabled
# -----------
# loading dataset : CIFAR10
# Train batches: 782, Validation batches: 157
# data sanity check
# image shape and labels shape in training data - one batch : torch.Size([64, 3, 32, 32]), torch.Size([64])
# Data Configuration:
#   dataset: CIFAR10
#   data_path: /home/wd/Documents/work_stuff/ViT_REPLICATION/data/CIFAR10
#   channels: 3
#   batch_size: 64
#   num_workers: 4
#   img_size: 32
#   mean_aug: [0.4914, 0.4822, 0.4465]
#   std_aug: [0.2023, 0.1994, 0.201]
#   num_classes: 10
# Model Configuration:
#   name: vit_small
#   patch_size: 4
#   emb_size: 512
#   depth: 10
#   num_heads: 8
#   mlp_ratio: 3.0
#   dropout: 0.3
# Training Configuration:
#   mixup: {'enabled': False, 'mixup_alpha': 0.2, 'cutmix_alpha': 0.1, 'label_smoothing_mixup': 0.1}
#   epochs: 200
#   lr: 0.01
#   weight_decay: 0.005
#   scheduler: False
#   scheduler_warmup: True
#   warmup_steps: 5
#   label_smoothing_enabled: True
#   label_smoothing: 0.1
# Total Trainable Parameters: 26,340,874 (26.34M)
# printing a few of the model weights - should be random and unique in every run.
# tensor([[ 0.0299,  0.0076,  0.1437,  0.1349],
#         [-0.0385,  0.1334, -0.0078, -0.1376],
#         [ 0.0803,  0.0264,  0.0603,  0.1400],
#         [-0.0105, -0.0172, -0.0234,  0.0789]], device='cuda:0',
#        grad_fn=<SliceBackward0>)
#
# Epoch 1/200
# Training:  96%|█████▋| 749/782 [01:48<00:04,  6.95it/s, Loss=2.0068, Acc=29.19%]

# %%
# !nvidia-smi
# Out:
# Thu Jun 12 17:39:08 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   70C    P0             47W /  250W |       0MiB /  16384MiB |     23%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
